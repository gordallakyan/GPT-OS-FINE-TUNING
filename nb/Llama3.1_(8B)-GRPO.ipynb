# %% [markdown]
# To run this, press "*Runtime*" and press "*Run all*" on a **free** Tesla T4 Google Colab instance!
# <div class="align-center">
# <a href="https://unsloth.ai/"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
# <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord button.png" width="145"></a>
# <a href="https://docs.unsloth.ai/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a></a> Join Discord if you need help + ⭐ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐
# </div>
#
# To install Unsloth on your own computer, follow the installation instructions on our Github page [here](https://docs.unsloth.ai/get-started/installing-+-updating).
#
# You will learn how to do [data prep](#Data), how to [train](#Train), how to [run the model](#Inference), & [how to save it](#Save)

# %% [markdown]
# ### News

# %% [markdown]
# Unsloth's [Docker image](https://hub.docker.com/r/unsloth/unsloth) is here! Start training with no setup & environment issues. [Read our Guide](https://docs.unsloth.ai/new/how-to-train-llms-with-unsloth-and-docker).
#
# [gpt-oss RL](https://docs.unsloth.ai/new/gpt-oss-reinforcement-learning) is now supported with the fastest inference & lowest VRAM. Try our [new notebook](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/gpt-oss-(20B)-GRPO.ipynb) which creates kernels!
#
# Introducing [Vision](https://docs.unsloth.ai/new/vision-reinforcement-learning-vlm-rl) and [Standby](https://docs.unsloth.ai/basics/memory-efficient-rl) for RL! Train Qwen, Gemma etc. VLMs with GSPO - even faster with less VRAM.
#
# Unsloth now supports Text-to-Speech (TTS) models. Read our [guide here](https://docs.unsloth.ai/basics/text-to-speech-tts-fine-tuning).
#
# Visit our docs for all our [model uploads](https://docs.unsloth.ai/get-started/all-our-models) and [notebooks](https://docs.unsloth.ai/get-started/unsloth-notebooks).

# %% [markdown]
# ### Installation

# %%
# %%capture
import os
os.environ["UNSLOTH_VLLM_STANDBY"] = "1" # [NEW] Extra 30% context lengths!
if "COLAB_" not in "".join(os.environ.keys()):
    # If you're not in Colab, just use pip install or uv pip install
    # !pip install unsloth vllm
else:
    pass # For Colab / Kaggle, we need extra instructions hidden below \/

# %%
#@title Colab Extra Install { display-mode: "form" }
# %%capture
import os
# !pip install --upgrade -qqq uv
if "COLAB_" not in "".join(os.environ.keys()):
    # If you're not in Colab, just use pip install!
    # !pip install unsloth vllm
else:
    try: import numpy; get_numpy = f"numpy=={numpy.__version__}"
    except: get_numpy = "numpy"
    try: import subprocess; is_t4 = "Tesla T4" in str(subprocess.check_output(["nvidia-smi"]))
    except: is_t4 = False
    get_vllm, get_triton = ("vllm==0.9.2", "triton==3.2.0") if is_t4 else ("vllm==0.10.2", "triton")
    # !uv pip install -qqq --upgrade \
        unsloth {get_vllm} {get_numpy} torchvision bitsandbytes xformers
    # !uv pip install -qqq {get_triton}
# !uv pip install transformers==4.55.4
# !uv pip install --no-deps trl==0.22.2

# %% [markdown]
# ### Unsloth

# %% [markdown]
# Load up `Llama 3.1 8B Instruct`, and set parameters

# %%
from unsloth import FastLanguageModel
import torch
max_seq_length = 1024 # Can increase for longer reasoning traces
lora_rank = 32 # Larger rank = smarter, but slower

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/meta-Llama-3.1-8B-Instruct",
    max_seq_length = max_seq_length,
    load_in_4bit = True, # False for LoRA 16bit
    fast_inference = True, # Enable vLLM fast inference
    max_lora_rank = lora_rank,
    gpu_memory_utilization = 0.9, # Reduce if out of memory
)

model = FastLanguageModel.get_peft_model(
    model,
    r = lora_rank, # Choose any number > 0 ! Suggested 8, 16, 32, 64, 128
    target_modules = [
        "q_proj", "k_proj", "v_proj", "o_proj",
        "gate_proj", "up_proj", "down_proj",
    ], # Remove QKVO if out of memory
    lora_alpha = lora_rank,
    use_gradient_checkpointing = "unsloth", # Enable long context finetuning
    random_state = 3407,
)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# INFO 10-03 14:02:54 [__init__.py:244] Automatically detected platform cuda.
# ERROR 10-03 14:02:57 [fa_utils.py:57] Cannot use FA version 2 is not supported due to FA2 is only supported on devices with compute capability >= 8
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# INFO 10-03 14:03:09 [vllm_utils.py:689] Unsloth: Patching vLLM v1 graph capture
# INFO 10-03 14:03:09 [vllm_utils.py:717] Unsloth: Patching vLLM v0 graph capture
# ==((====))==  Unsloth 2025.9.11: Fast Llama patching. Transformers: 4.55.4. vLLM: 0.9.2.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.741 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.7.0+cu126. CUDA: 7.5. CUDA Toolkit: 12.6. Triton: 3.2.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.30. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Unsloth: vLLM loading unsloth/meta-llama-3.1-8b-instruct-unsloth-bnb-4bit with actual GPU utilization = 89.15%
# Unsloth: Your GPU has CUDA compute capability 7.5 with VRAM = 14.74 GB.
# Unsloth: Using conservativeness = 1.0. Chunked prefill tokens = 1024. Num Sequences = 192.
# Unsloth: vLLM's KV Cache can use up to 6.97 GB. Also swap space = 0 GB.
# INFO 10-03 14:03:31 [config.py:841] This model supports multiple tasks: {'generate', 'reward', 'classify', 'embed'}. Defaulting to 'generate'.
# WARNING 10-03 14:03:31 [config.py:3371] Casting torch.bfloat16 to torch.float16.
# INFO 10-03 14:03:31 [config.py:1472] Using max model len 1024
# WARNING 10-03 14:03:31 [arg_utils.py:1735] Compute Capability < 8.0 is not supported by the V1 Engine. Falling back to V0.
# INFO 10-03 14:03:33 [config.py:2285] Chunked prefill is enabled with max_num_batched_tokens=2048.
# Unsloth: vLLM Bitsandbytes config using kwargs = {'load_in_8bit': False, 'load_in_4bit': True, 'bnb_4bit_compute_dtype': 'float16', 'bnb_4bit_quant_storage': 'uint8', 'bnb_4bit_quant_type': 'nf4', 'bnb_4bit_use_double_quant': True, 'llm_int8_enable_fp32_cpu_offload': False, 'llm_int8_has_fp16_weight': False, 'llm_int8_skip_modules': ['lm_head', 'multi_modal_projector', 'merger', 'modality_projection', 'model.layers.1.mlp'], 'llm_int8_threshold': 6.0}
# INFO 10-03 14:03:33 [llm_engine.py:230] Initializing a V0 LLM engine (v0.9.2) with config: model='unsloth/meta-llama-3.1-8b-instruct-unsloth-bnb-4bit', speculative_config=None, tokenizer='unsloth/meta-llama-3.1-8b-instruct-unsloth-bnb-4bit', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, override_neuron_config={}, tokenizer_revision=None, trust_remote_code=False, dtype=torch.float16, max_seq_len=1024, download_dir=None, load_format=LoadFormat.BITSANDBYTES, tensor_parallel_size=1, pipeline_parallel_size=1, disable_custom_all_reduce=False, quantization=bitsandbytes, enforce_eager=False, kv_cache_dtype=auto,  device_config=cuda, decoding_config=DecodingConfig(backend='auto', disable_fallback=False, disable_any_whitespace=False, disable_additional_properties=False, reasoning_backend=''), observability_config=ObservabilityConfig(show_hidden_metrics_for_version=None, otlp_traces_endpoint=None, collect_detailed_traces=None), seed=0, served_model_name=unsloth/meta-llama-3.1-8b-instruct-unsloth-bnb-4bit, num_scheduler_steps=1, multi_step_stream_outputs=True, enable_prefix_caching=True, chunked_prefill_enabled=True, use_async_output_proc=True, pooler_config=None, compilation_config={"level":0,"debug_dump_path":"","cache_dir":"","backend":"inductor","custom_ops":[],"splitting_ops":[],"use_inductor":true,"compile_sizes":[],"inductor_compile_config":{"epilogue_fusion":true,"max_autotune":false,"shape_padding":true,"trace.enabled":false,"triton.cudagraphs":true,"debug":false,"dce":true,"memory_planning":true,"coordinate_descent_tuning":false,"trace.graph_diagram":false,"compile_threads":4,"group_fusion":true,"disable_progress":false,"verbose_progress":true,"triton.multi_kernel":0,"triton.use_block_ptr":true,"triton.enable_persistent_tma_matmul":true,"triton.autotune_at_compile_time":false,"triton.cooperative_reductions":false,"cuda.compile_opt_level":"-O2","cuda.enable_cuda_lto":true,"combo_kernels":false,"benchmark_combo_kernel":true,"combo_kernel_foreach_dynamic_shapes":true,"enable_auto_functionalized_v2":false},"inductor_passes":{},"use_cudagraph":true,"cudagraph_num_of_warmups":1,"cudagraph_capture_sizes":[192,184,176,168,160,152,144,136,128,120,112,104,96,88,80,72,64,56,48,40,32,24,16,8,4,2,1],"cudagraph_copy_inputs":false,"full_cuda_graph":true,"max_capture_size":192,"local_cache_dir":null}, use_cached_outputs=False,
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.2M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/454 [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# INFO 10-03 14:03:39 [cuda.py:311] Cannot use FlashAttention-2 backend for Volta and Turing GPUs.
# INFO 10-03 14:03:39 [cuda.py:360] Using XFormers backend.
# INFO 10-03 14:03:40 [parallel_state.py:1076] rank 0 in world size 1 is assigned as DP rank 0, PP rank 0, TP rank 0, EP rank 0
# INFO 10-03 14:03:40 [model_runner.py:1171] Starting to load model unsloth/meta-llama-3.1-8b-instruct-unsloth-bnb-4bit...
# INFO 10-03 14:03:41 [bitsandbytes_loader.py:499] Loading weights with BitsAndBytes quantization. May take a while ...
# INFO 10-03 14:03:43 [weight_utils.py:292] Using model weights format ['*.safetensors']
# model.safetensors:   0%|          | 0.00/5.96G [00:00<?, ?B/s]
# INFO 10-03 14:04:32 [weight_utils.py:308] Time spent downloading weights for unsloth/meta-llama-3.1-8b-instruct-unsloth-bnb-4bit: 49.619773 seconds
# INFO 10-03 14:04:33 [weight_utils.py:345] No model.safetensors.index.json found in remote.
# Loading safetensors checkpoint shards:   0% Completed | 0/1 [00:00<?, ?it/s]
# Loading safetensors checkpoint shards:   0% Completed | 0/1 [00:00<?, ?it/s]
# INFO 10-03 14:05:02 [punica_selector.py:19] Using PunicaWrapperGPU.
# INFO 10-03 14:05:04 [model_runner.py:1203] Model loading took 5.7659 GiB and 81.534337 seconds
# INFO 10-03 14:05:15 [worker.py:294] Memory profiling takes 11.20 seconds
# INFO 10-03 14:05:15 [worker.py:294] the current vLLM instance can use total_gpu_memory (14.74GiB) x gpu_memory_utilization (0.89) = 13.14GiB
# INFO 10-03 14:05:15 [worker.py:294] model weights take 5.77GiB; non_torch_memory takes 0.03GiB; PyTorch activation peak memory takes 0.90GiB; the rest of the memory reserved for KV Cache is 6.45GiB.
# INFO 10-03 14:05:16 [executor_base.py:113] # cuda blocks: 3302, # CPU blocks: 0
# INFO 10-03 14:05:16 [executor_base.py:118] Maximum concurrency for 1024 tokens per request: 51.59x
# INFO 10-03 14:05:16 [vllm_utils.py:722] Unsloth: Running patched vLLM v0 `capture_model`.
# INFO 10-03 14:05:16 [model_runner.py:1513] Capturing cudagraphs for decoding. This may lead to unexpected consequences if the model is not static. To run the model in eager mode, set 'enforce_eager=True' or use '--enforce-eager' in the CLI. If out-of-memory error occurs during cudagraph capture, consider decreasing `gpu_memory_utilization` or switching to eager mode. You can also reduce the `max_num_seqs` as needed to decrease memory usage.
# Capturing CUDA graph shapes:   0%|          | 0/27 [00:00<?, ?it/s]
# INFO 10-03 14:05:43 [model_runner.py:1671] Graph capturing finished in 27 secs, took 0.59 GiB
# INFO 10-03 14:05:43 [vllm_utils.py:729] Unsloth: Patched vLLM v0 graph capture finished in 27 secs.
# INFO 10-03 14:05:44 [llm_engine.py:428] init engine (profile, create kv cache, warmup model) took 40.71 seconds
# Unsloth: Just some info: will skip parsing ['post_layernorm', 'post_attention_layernorm', 'q_norm', 'post_feedforward_layernorm', 'attention_norm', 'k_norm', 'pre_feedforward_layernorm', 'ffn_norm', 'layer_norm2', 'norm2', 'layer_norm1', 'norm1', 'input_layernorm']
# Unsloth: Just some info: will skip parsing ['post_layernorm', 'cross_attn_post_attention_layernorm', 'post_attention_layernorm', 'q_norm', 'post_feedforward_layernorm', 'attention_norm', 'k_norm', 'pre_feedforward_layernorm', 'ffn_norm', 'layer_norm2', 'norm2', 'cross_attn_input_layernorm', 'layer_norm1', 'norm1', 'input_layernorm']
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/454 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.2M [00:00<?, ?B/s]
# Unsloth 2025.9.11 patched 32 layers with 32 QKV layers, 32 O layers and 32 MLP layers.

# %% [markdown]
# ### Data Prep
# <a name="Data"></a>
#
# We directly leverage [@willccbb](https://gist.github.com/willccbb/4676755236bb08cab5f4e54a0475d6fb) for data prep and all reward functions. You are free to create your own!

# %%
import re
from datasets import load_dataset, Dataset

# Load and prep dataset
SYSTEM_PROMPT = """
Respond in the following format:
<reasoning>
...
</reasoning>
<answer>
...
</answer>
"""

XML_COT_FORMAT = """\
<reasoning>
{reasoning}
</reasoning>
<answer>
{answer}
</answer>
"""

def extract_xml_answer(text: str) -> str:
    answer = text.split("<answer>")[-1]
    answer = answer.split("</answer>")[0]
    return answer.strip()

def extract_hash_answer(text: str) -> str | None:
    if "####" not in text:
        return None
    return text.split("####")[1].strip()

# uncomment middle messages for 1-shot prompting
def get_gsm8k_questions(split = "train") -> Dataset:
    data = load_dataset('openai/gsm8k', 'main')[split] # type: ignore
    data = data.map(lambda x: { # type: ignore
        'prompt': [
            {'role': 'system', 'content': SYSTEM_PROMPT},
            {'role': 'user', 'content': x['question']}
        ],
        'answer': extract_hash_answer(x['answer'])
    }) # type: ignore
    return data # type: ignore

dataset = get_gsm8k_questions()

# Reward functions
def correctness_reward_func(prompts, completions, answer, **kwargs) -> list[float]:
    responses = [completion[0]['content'] for completion in completions]
    q = prompts[0][-1]['content']
    extracted_responses = [extract_xml_answer(r) for r in responses]
    print('-'*20, f"Question:\n{q}", f"\nAnswer:\n{answer[0]}", f"\nResponse:\n{responses[0]}", f"\nExtracted:\n{extracted_responses[0]}")
    return [2.0 if r == a else 0.0 for r, a in zip(extracted_responses, answer)]

def int_reward_func(completions, **kwargs) -> list[float]:
    responses = [completion[0]['content'] for completion in completions]
    extracted_responses = [extract_xml_answer(r) for r in responses]
    return [0.5 if r.isdigit() else 0.0 for r in extracted_responses]

def strict_format_reward_func(completions, **kwargs) -> list[float]:
    """Reward function that checks if the completion has a specific format."""
    pattern = r"^<reasoning>\n.*?\n</reasoning>\n<answer>\n.*?\n</answer>\n$"
    responses = [completion[0]["content"] for completion in completions]
    matches = [re.match(pattern, r) for r in responses]
    return [0.5 if match else 0.0 for match in matches]

def soft_format_reward_func(completions, **kwargs) -> list[float]:
    """Reward function that checks if the completion has a specific format."""
    pattern = r"<reasoning>.*?</reasoning>\s*<answer>.*?</answer>"
    responses = [completion[0]["content"] for completion in completions]
    matches = [re.match(pattern, r) for r in responses]
    return [0.5 if match else 0.0 for match in matches]

def count_xml(text) -> float:
    count = 0.0
    if text.count("<reasoning>\n") == 1:
        count += 0.125
    if text.count("\n</reasoning>\n") == 1:
        count += 0.125
    if text.count("\n<answer>\n") == 1:
        count += 0.125
        count -= len(text.split("\n</answer>\n")[-1])*0.001
    if text.count("\n</answer>") == 1:
        count += 0.125
        count -= (len(text.split("\n</answer>")[-1]) - 1)*0.001
    return count

def xmlcount_reward_func(completions, **kwargs) -> list[float]:
    contents = [completion[0]["content"] for completion in completions]
    return [count_xml(c) for c in contents]
# Out:
# README.md: 0.00B [00:00, ?B/s]
# main/train-00000-of-00001.parquet:   0%|          | 0.00/2.31M [00:00<?, ?B/s]
# main/test-00000-of-00001.parquet:   0%|          | 0.00/419k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/7473 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/1319 [00:00<?, ? examples/s]
# Map:   0%|          | 0/7473 [00:00<?, ? examples/s]

# %% [markdown]
# <a name="Train"></a>
# ### Train the model
#
# Now set up GRPO Trainer and all configurations!

# %%
max_prompt_length = 256

from trl import GRPOConfig, GRPOTrainer
training_args = GRPOConfig(
    learning_rate = 5e-6,
    adam_beta1 = 0.9,
    adam_beta2 = 0.99,
    weight_decay = 0.1,
    warmup_ratio = 0.1,
    lr_scheduler_type = "cosine",
    optim = "paged_adamw_8bit",
    logging_steps = 1,
    per_device_train_batch_size = 1,
    gradient_accumulation_steps = 1, # Increase to 4 for smoother training
    num_generations = 6, # Decrease if out of memory
    max_prompt_length = max_prompt_length,
    max_completion_length = max_seq_length - max_prompt_length,
    # num_train_epochs = 1, # Set to 1 for a full training run
    max_steps = 250,
    save_steps = 250,
    max_grad_norm = 0.1,
    report_to = "none", # Can use Weights & Biases
    output_dir = "outputs",
)
# Out:
# Unsloth: We now expect `per_device_train_batch_size` to be a multiple of `num_generations`.
# We will change the batch size of 1 to the `num_generations` of 6

# %% [markdown]
# And let's run the trainer! If you scroll up, you'll see a table of rewards. The goal is to see the `reward` column increase!
#
# You might have to wait 150 to 200 steps for any action. You'll probably get 0 reward for the first 100 steps. Please be patient!
#
# | Step | Training Loss | reward    | reward_std | completion_length | kl       |
# |------|---------------|-----------|------------|-------------------|----------|
# | 1    | 0.000000      | 0.125000  | 0.000000   | 200.000000        | 0.000000 |
# | 2    | 0.000000      | 0.072375  | 0.248112   | 200.000000        | 0.000000 |
# | 3    | 0.000000      | -0.079000 | 0.163776   | 182.500000        | 0.000005 |

# %%
trainer = GRPOTrainer(
    model = model,
    processing_class = tokenizer,
    reward_funcs = [
        xmlcount_reward_func,
        soft_format_reward_func,
        strict_format_reward_func,
        int_reward_func,
        correctness_reward_func,
    ],
    args = training_args,
    train_dataset = dataset,
)
trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 7,473 | Num Epochs = 1 | Total steps = 250
# O^O/ \_/ \    Batch size per device = 6 | Gradient accumulation steps = 1
# \        /    Data Parallel GPUs = 1 | Total batch size (6 x 1 x 1) = 6
#  "-____-"     Trainable parameters = 83,886,080 of 8,114,147,328 (1.03% trained)
# -------------------- Question:
# A concert ticket costs $40. Mr. Benson bought 12 tickets and received a 5% discount for every ticket bought that exceeds 10. How much did Mr. Benson pay in all?
# Answer:
# 476
# Response:
# Let's break down the problem:
#
# 1. The first 10 tickets will be priced at the full price of $40.
# 2. The remaining 2 tickets (12 - 10 = 2) qualify for a 5% discount.
#
# First, calculate the cost of the first 10 tickets:
# 10 tickets * $40 = $400
#
# For the 2 tickets with the discount, calculate the discount:
# 2 tickets * 5% = 2 * $40 * 5% = 2 * $40 * 0.05 = $4 per ticket
#
# So, the discounted price for each of the 2 tickets is:
# $40 - $4 = $36 per ticket
#
# Now, calculate the cost of the 2 discounted tickets:
# 2 tickets * $36 = $72
#
# Now, add the cost of the discounted tickets to the cost of the first 10 tickets:
# $400 + $72 = $472
#
# <answer> $472
# Extracted:
# $472
#     <div>
#
#       <progress value='30' max='250' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 30/250 24:46 < 3:14:35, 0.02 it/s, Epoch 0.00/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>reward</th>
#       <th>reward_std</th>
#       <th>completions / mean_length</th>
#       <th>completions / min_length</th>
#       <th>completions / max_length</th>
#       <th>completions / clipped_ratio</th>
#       <th>completions / mean_terminated_length</th>
#       <th>completions / min_terminated_length</th>
#       <th>completions / max_terminated_length</th>
#       <th>kl</th>
#       <th>rewards / xmlcount_reward_func / mean</th>
#       <th>rewards / xmlcount_reward_func / std</th>
#       <th>rewards / soft_format_reward_func / mean</th>
#       <th>rewards / soft_format_reward_func / std</th>
#       <th>rewards / strict_format_reward_func / mean</th>
#       <th>rewards / strict_format_reward_func / std</th>
#       <th>rewards / int_reward_func / mean</th>
#       <th>rewards / int_reward_func / std</th>
#       <th>rewards / correctness_reward_func / mean</th>
#       <th>rewards / correctness_reward_func / std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>-0.000000</td>
#       <td>0.327833</td>
#       <td>1.085287</td>
#       <td>193.833344</td>
#       <td>157.000000</td>
#       <td>232.000000</td>
#       <td>0.000000</td>
#       <td>193.833344</td>
#       <td>157.000000</td>
#       <td>232.000000</td>
#       <td>0.000000</td>
#       <td>-0.088833</td>
#       <td>0.217596</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.083333</td>
#       <td>0.204124</td>
#       <td>0.333333</td>
#       <td>0.816497</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>313.000000</td>
#       <td>214.000000</td>
#       <td>432.000000</td>
#       <td>0.000000</td>
#       <td>313.000000</td>
#       <td>214.000000</td>
#       <td>432.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>-0.000000</td>
#       <td>-0.050500</td>
#       <td>0.123699</td>
#       <td>179.000000</td>
#       <td>117.000000</td>
#       <td>218.000000</td>
#       <td>0.000000</td>
#       <td>179.000000</td>
#       <td>117.000000</td>
#       <td>218.000000</td>
#       <td>0.000004</td>
#       <td>-0.050500</td>
#       <td>0.123699</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.000000</td>
#       <td>1.242667</td>
#       <td>1.361368</td>
#       <td>175.666672</td>
#       <td>128.000000</td>
#       <td>239.000000</td>
#       <td>0.000000</td>
#       <td>175.666672</td>
#       <td>128.000000</td>
#       <td>239.000000</td>
#       <td>0.000005</td>
#       <td>-0.007333</td>
#       <td>0.017963</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.250000</td>
#       <td>0.273861</td>
#       <td>1.000000</td>
#       <td>1.095445</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.000000</td>
#       <td>0.422667</td>
#       <td>0.999715</td>
#       <td>115.166672</td>
#       <td>98.000000</td>
#       <td>142.000000</td>
#       <td>0.000000</td>
#       <td>115.166672</td>
#       <td>98.000000</td>
#       <td>142.000000</td>
#       <td>0.000006</td>
#       <td>-0.077333</td>
#       <td>0.111491</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.166667</td>
#       <td>0.258199</td>
#       <td>0.333333</td>
#       <td>0.816497</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.000000</td>
#       <td>1.167000</td>
#       <td>1.471507</td>
#       <td>213.500000</td>
#       <td>173.000000</td>
#       <td>237.000000</td>
#       <td>0.000000</td>
#       <td>213.500000</td>
#       <td>173.000000</td>
#       <td>237.000000</td>
#       <td>0.000004</td>
#       <td>-0.083000</td>
#       <td>0.203308</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.250000</td>
#       <td>0.273861</td>
#       <td>1.000000</td>
#       <td>1.095445</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>382.000000</td>
#       <td>155.000000</td>
#       <td>768.000000</td>
#       <td>0.166667</td>
#       <td>304.800018</td>
#       <td>155.000000</td>
#       <td>444.000000</td>
#       <td>0.000007</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.000000</td>
#       <td>-0.193333</td>
#       <td>0.328000</td>
#       <td>195.166672</td>
#       <td>112.000000</td>
#       <td>334.000000</td>
#       <td>0.000000</td>
#       <td>195.166672</td>
#       <td>112.000000</td>
#       <td>334.000000</td>
#       <td>0.000010</td>
#       <td>-0.193333</td>
#       <td>0.328000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.000000</td>
#       <td>1.136667</td>
#       <td>1.513957</td>
#       <td>158.833344</td>
#       <td>123.000000</td>
#       <td>210.000000</td>
#       <td>0.000000</td>
#       <td>158.833344</td>
#       <td>123.000000</td>
#       <td>210.000000</td>
#       <td>0.000006</td>
#       <td>-0.113333</td>
#       <td>0.277609</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.250000</td>
#       <td>0.273861</td>
#       <td>1.000000</td>
#       <td>1.095445</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>244.666672</td>
#       <td>147.000000</td>
#       <td>435.000000</td>
#       <td>0.000000</td>
#       <td>244.666672</td>
#       <td>147.000000</td>
#       <td>435.000000</td>
#       <td>0.000007</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>175.166672</td>
#       <td>123.000000</td>
#       <td>261.000000</td>
#       <td>0.000000</td>
#       <td>175.166672</td>
#       <td>123.000000</td>
#       <td>261.000000</td>
#       <td>0.000009</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.000000</td>
#       <td>0.379500</td>
#       <td>0.929581</td>
#       <td>162.833344</td>
#       <td>140.000000</td>
#       <td>197.000000</td>
#       <td>0.000000</td>
#       <td>162.833344</td>
#       <td>140.000000</td>
#       <td>197.000000</td>
#       <td>0.000013</td>
#       <td>-0.037167</td>
#       <td>0.091039</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.083333</td>
#       <td>0.204124</td>
#       <td>0.333333</td>
#       <td>0.816497</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.000000</td>
#       <td>0.943333</td>
#       <td>1
# Unsloth: Will smartly offload gradients to save VRAM!
# -------------------- Question:
# Jane is trying to decide whether to buy a house or a trailer. A house costs $480,000 and a trailer costs $120,000. Each loan will be paid in monthly installments over 20 years. How much more is the monthly payment on the house compared to the trailer?
# Answer:
# 1500
# Response:
# To find the monthly payment difference, we need to find the monthly payment for each option and then subtract the trailer payment from the house payment.
#
# The formula for monthly payment is M = P[r(1+r)^n]/[(1+r)^n - r], where P is the principal (initial cost), r is the monthly interest rate, and n is the number of payments (months).
#
# However, we don't know the interest rate. If we assume the interest rate is the same for both the house and the trailer, the interest rate difference would be the same regardless of the loan amount, which means it would cancel out when subtracting the payments.
#
# Instead we can use another method, the ratio of the two loans. Assuming a fixed interest rate, the monthly payment is proportional to the principal and the number of months.
#
# For the trailer:   $120,000 / 20 * 12
#                   = $720
# For the house:    $480,000 / 20 * 12
#                   = $2880
#
# $2880 - $720
# $2160
# Extracted:
# To find the monthly payment difference, we need to find the monthly payment for each option and then subtract the trailer payment from the house payment.
#
# The formula for monthly payment is M = P[r(1+r)^n]/[(1+r)^n - r], where P is the principal (initial cost), r is the monthly interest rate, and n is the number of payments (months).
#
# However, we don't know the interest rate. If we assume the interest rate is the same for both the house and the trailer, the interest rate difference would be the same regardless of the loan amount, which means it would cancel out when subtracting the payments.
#
# Instead we can use another method, the ratio of the two loans. Assuming a fixed interest rate, the monthly payment is proportional to the principal and the number of months.
#
# For the trailer:   $120,000 / 20 * 12
#                   = $720
# For the house:    $480,000 / 20 * 12
#                   = $2880
#
# $2880 - $720
# $2160
# -------------------- Question:
# Janet pays $40/hour for 3 hours per week of clarinet lessons and $28/hour for 5 hours a week of piano lessons. How much more does she spend on piano lessons than clarinet lessons in a year?
# Answer:
# 1040
# Response:
# First, let's calculate how much Janet spends on clarinet lessons and piano lessons per week.
# Clarinet lessons weekly cost: $40/hour * 3 hours = $120/week
# Piano lessons weekly cost: $28/hour * 5 hours = $140/week
# To find out how much more she spends on piano lessons than clarinet lessons per week, we need to subtract the weekly cost of the clarinet lessons from the weekly cost of the piano lessons.
# Difference in a week: $140/week - $120/week = $20/week
# To find out how much more she spends on piano lessons than clarinet lessons in a year, we multiply the weekly difference by the number of weeks in a year. There are 52 weeks in a year.
# Difference in a year: $20/week * 52 weeks/year = $1040/year
# <answer> $1040 </answer>
# Extracted:
# $1040
# -------------------- Question:
# Sabrina is collecting herbs to make a poultice for her grandmother. She needs twice as many basil leaves as sage leaves and 5 fewer sage leaves than verbena leaves. If she needs 12 basil leaves, how many leaves total does she need?
# Answer:
# 29
# Response:
# Let's break this down step by step.
#
# We know that Sabrina needs twice as many basil leaves as sage leaves, and she needs 12 basil leaves.
#
# Since she needs 12 basil leaves and she needs twice as many basil leaves as sage leaves, she must need half as many sage leaves as basil leaves, which is 12 / 2 = 6 sage leaves.
#
# We also know that she needs 5 fewer sage leaves than verbena leaves. To find the number of verbena leaves, we add 5 to the number of sage leaves: 6 + 5 = 11 verbena leaves.
#
# To find the total number of leaves Sabrina needs, we add up the number of basil leaves, sage leaves, and verbena leaves: 12 (basil) + 6 (sage) + 11 (verbena) = 29.
#
# <answer> 29.
# Extracted:
# 29.
# -------------------- Question:
# Over the past five years, on July 4th, the high temperature for Washington, DC has been: 90 degrees in 2020, 90 degrees in 2019, 90 degrees in 2018, 79 degrees in 2017 and 71 degrees in 2016. What is the average temperature for July 4th in Washington, DC over the past 5 years?
# Answer:
# 84
# Response:
# To find the average temperature, we need to add up the temperatures of the past five years and divide by 5.
#
# The temperatures are: 90, 90, 90, 79, 71.
#
# First, we add the temperatures together:
#
# 90 + 90 = 180
# 180 + 90 = 270
# 270 + 79 = 349
# 349 + 71 = 420
#
# Now, we divide the total temperature by 5:
#
# 420 / 5 = 84
#
# <answer>
# The average temperature for July 4th in Washington, DC over the past 5 years is 84 degrees.
# Extracted:
# The average temperature for July 4th in Washington, DC over the past 5 years is 84 degrees.
# -------------------- Question:
# Rene can finish reading 30 pages in 60 minutes. Lulu can read 27 pages in 60 minutes and Cherry can read 25 pages in 60 minutes. If they have been reading for 240 minutes now, how many pages have they finished reading in total?
# Answer:
# 328
# Response:
# To find out the total number of pages they have finished reading in 240 minutes, we first need to find the number of pages each of them read.
#
# Rene reads 30 pages in 60 minutes, so in 240 minutes she would read
# (30 pages / 60 minutes) * 240 minutes = 120 pages.
#
# Lulu reads 27 pages in 60 minutes, so in 240 minutes she would read
# (27 pages / 60 minutes) * 240 minutes = 108 pages.
#
# Cherry reads 25 pages in 60 minutes, so in 240 minutes she would read
# (25 pages / 60 minutes) * 240 minutes = 100 pages.
#
# Now, add the number of pages each of them read: 120 + 108 + 100 = 328.
#
# <reasoning>
# They were reading for 240 minutes. To find out the number of pages they finished, we have to use their reading rate (pages per minute), multiply it by the time they were reading (240 minutes) and calculate for each person separately before adding.
# </reasoning>
# <answer>
# 328 pages.
# Extracted:
# 328 pages.
# -------------------- Question:
# Martin rings the small bell 4 times more than 1/3 as often as the big bell. If he rings both of them a combined total of 52 times, how many times does he ring the big bell?
# Answer:
# 36
# Response:
# Let's break this down step by step:
#
# Let x be the number of times the big bell rings.
#
# Since Martin rings the small bell 4 times more than 1/3 as often as the big bell, we can express this as 4 + (1/3)x.
#
# The total number of times the two bells are rung is equal to the sum of the number of times each one is rung, which is given as 52. So we can write the equation:
#
# x + [4 + (1/3)x] = 52
#
# To simplify the equation, combine like terms:
#
# (1)3/3.[x + 4] = 52
#
# (3x + 12) / 3 = 52
#
# Now, divide both sides by 3:
#
# 3x + 12 = 156
#
# Subtract 12 from both sides:
#
# 3x = 144
#
# Divide both sides by 3:
#
# x = 48
#
# Therefore, the big bell rings 48 times.
# Extracted:
# Let's break this down step by step:
#
# Let x be the number of times the big bell rings.
#
# Since Martin rings the small bell 4 times more than 1/3 as often as the big bell, we can express this as 4 + (1/3)x.
#
# The total number of times the two bells are rung is equal to the sum of the number of times each one is rung, which is given as 52. So we can write the equation:
#
# x + [4 + (1/3)x] = 52
#
# To simplify the equation, combine like terms:
#
# (1)3/3.[x + 4] = 52
#
# (3x + 12) / 3 = 52
#
# Now, divide both sides by 3:
#
# 3x + 12 = 156
#
# Subtract 12 from both sides:
#
# 3x = 144
#
# Divide both sides by 3:
#
# x = 48
#
# Therefore, the big bell rings 48 times.
# -------------------- Question:
# Bert fills out the daily crossword puzzle in the newspaper every day. He uses up a pencil to fill out the puzzles every two weeks. On average, it takes him 1050 words to use up a pencil. How many words are in each crossword puzzle on average?
# Answer:
# 75
# Response:
# <step 1>
# To find the average number of words in each crossword puzzle, we first need to determine how many words Bert fills out in two weeks. Since he uses up a pencil every two weeks and it takes him 1050 words, the total words for two weeks is 1050.
#
# </step 1>
#
# <step 2>
# There are seven days in a week, so for two weeks, there would be 7 * 2 = 14 days. The number of words in each day's crossword puzzle is 1050 / 14.
#
# </step 2>
#
# <answer>
# 1050 / 14 is 75.
# </answer>
# Extracted:
# 1050 / 14 is 75.
# -------------------- Question:
# Matt can make a batch of a dozen cookies using 2 pounds of flour.  He uses 4 bags of flour each weighing 5 pounds.  If Jim eats 15 cookies how many cookies are left?
# Answer:
# 105
# Response:
# To determine the total number of cookies left after Jim eats 15, we need to first calculate the total number of cookies Matt can make from 20 pounds of flour.
#
# 1. Calculate the number of cookies Matt can make from 2 pounds of flour: Mathematically, 12 cookies / 2 pounds of flour is 6 cookies per pound of flour.
# Therefore, from 20 pounds of flour, Matt can make 6 cookies/pound * 20 pounds = 120 cookies.
#
# 2. Now we will subtract 15 cookies that Jim ate from 120 cookies to find the number of cookies that Matt has left.
# 120 cookies - 15 cookies = 105 cookies.
#
# So Matt has 105 cookies left.
# Extracted:
# To determine the total number of cookies left after Jim eats 15, we need to first calculate the total number of cookies Matt can make from 20 pounds of flour.
#
# 1. Calculate the number of cookies Matt can make from 2 pounds of flour: Mathematically, 12 cookies / 2 pounds of flour is 6 cookies per pound of flour.
# Therefore, from 20 pounds of flour, Matt can make 6 cookies/pound * 20 pounds = 120 cookies.
#
# 2. Now we will subtract 15 cookies that Jim ate from 120 cookies to find the number of cookies that Matt has left.
# 120 cookies - 15 cookies = 105 cookies.
#
# So Matt has 105 cookies left.
# -------------------- Question:
# James decides to build a tin house by collecting 500 tins in a week. On the first day, he collects 50 tins. On the second day, he manages to collect 3 times that number. On the third day, he collects 50 tins fewer than the number he collected on the second day. If he collects an equal number of tins on the remaining days of the week, what's the number of tins he collected each day for the rest of the week?
# Answer:
# 50
# Response:
# Opcode reconsideration would be appropriate here for accuracy.
#
# Let's break down James' collection over the first three days:
#
# Day 1: 50 tins
# Day 2: 3 times Day 1's amount, which is 50 * 3 = 150 tins
# Day 3: 50 tins fewer than Day 2's amount, which is 150 - 50 = 100 tins
#
# In total, James collected 50 + 150 + 100 = 300 tins in the first 3 days.
#
# Now, he still needs to collect 500 - 300 = 200 tins in the remaining 4 days.
#
# Since he collects an equal number of tins each day, he would collect 200 / 4 = 50 tins per day for the rest of the week.
#
# Therefore, the number of tins he has to collect each day for the rest of the week is 50.
# Extracted:
# Opcode reconsideration would be appropriate here for accuracy.
#
# Let's break down James' collection over the first three days:
#
# Day 1: 50 tins
# Day 2: 3 times Day 1's amount, which is 50 * 3 = 150 tins
# Day 3: 50 tins fewer than Day 2's amount, which is 150 - 50 = 100 tins
#
# In total, James collected 50 + 150 + 100 = 300 tins in the first 3 days.
#
# Now, he still needs to collect 500 - 300 = 200 tins in the remaining 4 days.
#
# Since he collects an equal number of tins each day, he would collect 200 / 4 = 50 tins per day for the rest of the week.
#
# Therefore, the number of tins he has to collect each day for the rest of the week is 50.
# -------------------- Question:
# A jar of jellybeans has 14 blue jellybeans, 26 purple jellybeans and 40 orange jellybeans. If there are 200 jellybeans in the jar, how many are there of the red color?
# Answer:
# 120
# Response:
# We are given the number of blue, purple, and orange jellybeans in the jar, with 14 + 26 + 40 = 80 jellybeans of these colors.
#
# We also know that there are a total of 200 jellybeans in the jar. To find the number of red jellybeans, we subtract the number of non-red jellybeans from the total number of jellybeans:
#
# Number of red jellybeans = Total number of jellybeans - Number of non-red jellybeans
# = 200 - 80
# = 120
#
# Therefore, there are 120 red jellybeans in the jar.
# Extracted:
# We are given the number of blue, purple, and orange jellybeans in the jar, with 14 + 26 + 40 = 80 jellybeans of these colors.
#
# We also know that there are a total of 200 jellybeans in the jar. To find the number of red jellybeans, we subtract the number of non-red jellybeans from the total number of jellybeans:
#
# Number of red jellybeans = Total number of jellybeans - Number of non-red jellybeans
# = 200 - 80
# = 120
#
# Therefore, there are 120 red jellybeans in the jar.
# -------------------- Question:
# Five adults and two children go to see a movie and buy $12 worth of concessions. The total cost of their trip is $76. If each child's ticket is $7, how much, in dollars, are the adult tickets?
# Answer:
# 10
# Response:
# Let's break this problem down step by step.
#
# Let a be the price of an adult ticket.
# However, we first need to calculate the total cost of adult and child tickets. We know the total cost of their tickets and concessions is $76, and they also spent $12 on concessions. So, the total cost of their tickets is $76 - $12 = $64.
# We know that there are 5 adults and 2 children. The cost of 2 children's tickets is 2 * $7 = $14. Therefore, the cost of the adults' tickets is $64 - $14 = $50. Now, we can set up an equation to represent the cost of the adult tickets:
# 5a = $50
# To find the cost of a single adult ticket, we need to divide both sides of the equation by 5.
# a = $50 / 5
# a = $10
#
# Therefore, the adult tickets are $10 each.
# Extracted:
# Let's break this problem down step by step.
#
# Let a be the price of an adult ticket.
# However, we first need to calculate the total cost of adult and child tickets. We know the total cost of their tickets and concessions is $76, and they also spent $12 on concessions. So, the total cost of their tickets is $76 - $12 = $64.
# We know that there are 5 adults and 2 children. The cost of 2 children's tickets is 2 * $7 = $14. Therefore, the cost of the adults' tickets is $64 - $14 = $50. Now, we can set up an equation to represent the cost of the adult tickets:
# 5a = $50
# To find the cost of a single adult ticket, we need to divide both sides of the equation by 5.
# a = $50 / 5
# a = $10
#
# Therefore, the adult tickets are $10 each.
# -------------------- Question:
# Janelle had 26 green marbles. Then she bought 6 bags of blue marbles. There were 10 marbles in each bag.  She created a gift of 6 green marbles and 8 blue marbles and gave it to a friend. How many marbles does Janelle have now?
# Answer:
# 72
# Response:
# To solve this problem, we first need to calculate the number of blue marbles Janelle bought. Since Janelle bought 6 bags of blue marbles and there were 10 marbles in each bag, the total number of blue marbles Janelle bought is 6 x 10 = 60 blue marbles.
#
# Initially, Janelle had 26 green marbles. She gave away a gift of 6 green marbles to her friend, leaving her with 26 - 6 = 20 green marbles.
#
# Janelle gave away a gift of 6 green marbles and 8 blue marbles, so she also gave away a total of 14 marbles. We previously calculated that Janelle bought 60 blue marbles. After giving away the gift, she has 60 - 8 = 52 blue marbles left.
#
# To find the total number of marbles Janelle has now, we need to add the remaining green marbles and blue marbles. The total is 20 + 52 = 72 marbles.
#
# <reasoning>
# 1. Calculate the number of blue marbles bought by Janelle.
# 2. Determine the number of marbles given away in the gift.
# 3. Calculate the remaining number of blue marbles after the gift.
# 4. Calculate the total number of remaining marbles.
# </reasoning>
# <answer>
# 72</answer>
# Extracted:
# 72
# -------------------- Question:
# Every day in a week, Siena bookmarks 30 website pages from the research she does on her browser. If Siena has 400 bookmarked pages on her bookmarks library now, how many pages will she have in her bookmarks library at the end of March?
# Answer:
# 1330
# Response:
# Assuming Siena starts with 400 bookmarked pages on January 1st, she bookmarks 30 pages every day. March has 31 days (1st to 31st inklusive).
#
# Since January and February also have 31 and 28 days respectively, every day Siena has bookmarked a total of 31 + 28 + 31 = 90 days.
# Then 30 bookmarks/day * 90 days = 2700 bookmarks in January & February and March from her initial 0 bookmarks isn't possible, thus excluding the initial 400 bookmarks.
#
# But Siena bookmarks 30 pages which if calculated for the full month will be,
# 30 * 31 * 3 = 2970 pages.
# At the end of March, if considering only March, her bookmarks would be,
#    The 2970 bookmarked pages which was calculated assuming she bookmarks 30/day.
# Extracted:
# Assuming Siena starts with 400 bookmarked pages on January 1st, she bookmarks 30 pages every day. March has 31 days (1st to 31st inklusive).
#
# Since January and February also have 31 and 28 days respectively, every day Siena has bookmarked a total of 31 + 28 + 31 = 90 days.
# Then 30 bookmarks/day * 90 days = 2700 bookmarks in January & February and March from her initial 0 bookmarks isn't possible, thus excluding the initial 400 bookmarks.
#
# But Siena bookmarks 30 pages which if calculated for the full month will be,
# 30 * 31 * 3 = 2970 pages.
# At the end of March, if considering only March, her bookmarks would be,
#    The 2970 bookmarked pages which was calculated assuming she bookmarks 30/day.
# -------------------- Question:
# An old pirate wants to leave his treasure on an island. He has 3500 gold coins. He wants to spread this equally across 5 chests. Additionally, he will put a total of 500 silver coins and twice as many bronze coins as silver, all distributed equally across the chests. How many coins in total will be in each chest?
# Answer:
# 1000
# Response:
# First, let's calculate the number of bronze coins. Since there are twice as many bronze coins as silver coins, and there are 500 silver coins, we have 2 * 500 = 1000 bronze coins.
#
# Now, let's add up the total number of coins we have: 3500 (gold) + 500 (silver) + 1000 (bronze) = 6000 coins.
#
# Since the pirate wants to spread the coins across 5 chests, we need to divide the total number of coins by 5: 6000 / 5 = 1200 coins per chest.
#
# <answer> 1200 </answer>
# Extracted:
# 1200
# -------------------- Question:
# Ephraim has two machines that make necklaces for his store. On Sunday the first machine made 45 necklaces. The second machine made 2.4 times as many necklaces as the first machine. How many necklaces were made in total on Sunday?
# Answer:
# 153
# Response:
# To find the number of necklaces made by the second machine, we need to multiply the number of necklaces made by the first machine (45) by 2.4.
#
# 2.4 * 45 = 108
#
# The second machine made 108 necklaces.
#
# To find the total number of necklaces made on Sunday, we need to add the number of necklaces made by the first machine (45) and the second machine (108).
#
# 45 + 108 = 153
#
# The total number of necklaces made on Sunday is 153.
# Extracted:
# To find the number of necklaces made by the second machine, we need to multiply the number of necklaces made by the first machine (45) by 2.4.
#
# 2.4 * 45 = 108
#
# The second machine made 108 necklaces.
#
# To find the total number of necklaces made on Sunday, we need to add the number of necklaces made by the first machine (45) and the second machine (108).
#
# 45 + 108 = 153
#
# The total number of necklaces made on Sunday is 153.
# -------------------- Question:
# Zach baked cookies for a bake sale. On Monday he baked 32 cookies. On Tuesday he ran out of sugar and could only bake half of the number of cookies he baked the day before. On Wednesday he baked three times the number of cookies he did on Tuesday, but his brother ate 4 of those cookies. How many cookies did he have at the end of the three days?
# Answer:
# 92
# Response:
# On Monday, Zach baked 32 cookies.
# On Tuesday, he baked half of the 32 cookies, which is 32 / 2 = 16 cookies.
# On Wednesday, he baked three times the number of cookies he did on Tuesday, which is 16 * 3 = 48 cookies, but his brother ate 4 of those cookies. So, he had 48 - 4 = 44 cookies on Wednesday.
#
# To find the total number of cookies at the end of the three days, we need to add the number of cookies Zach had at the end of each day:
# - Monday: 32 cookies
# - Tuesday: 32 - 16 = 16 cookies
# - Wednesday: 16 + 44 = 60 cookies
#
# Total number of cookies at the end of three days = 32 + 16 + 60 = 108 cookies
# Extracted:
# On Monday, Zach baked 32 cookies.
# On Tuesday, he baked half of the 32 cookies, which is 32 / 2 = 16 cookies.
# On Wednesday, he baked three times the number of cookies he did on Tuesday, which is 16 * 3 = 48 cookies, but his brother ate 4 of those cookies. So, he had 48 - 4 = 44 cookies on Wednesday.
#
# To find the total number of cookies at the end of the three days, we need to add the number of cookies Zach had at the end of each day:
# - Monday: 32 cookies
# - Tuesday: 32 - 16 = 16 cookies
# - Wednesday: 16 + 44 = 60 cookies
#
# Total number of cookies at the end of three days = 32 + 16 + 60 = 108 cookies
# -------------------- Question:
# Mark and James need a total of 14 dice that are 12 sided to play their game.  Mark has a bag of 10 dice and 60% of them are 12 sided.  James has a bag of 8 dice and 75% of them are 12 sided.  How many dice will the boys need to buy to play their game?
# Answer:
# 2
# Response:
# reasoning:
# To find out how many 12 sided dice Mark and James need to buy, we need to calculate the number of 12 sided dice each of them already has and the total number of 12 sided dice Mark and James have in their bags combined.
#
# Mark has 10 dice, and 60% of them are 12 sided. So, Mark has 60% of 10 dice = 0.6 * 10 = 6 twelve-sided dice.
#
# James has 8 dice, and 75% of them are 12 sided. So, James has 75% of 8 dice = 0.75 * 8 = 6 twelve-sided dice.
#
# Mark and James have a total of 6 + 6 = 12 twelve-sided dice. They need a total of 14 dice.
#
# answer:
# Since they already have 12 twelve-sided dice, they need to buy 14 - 12 = 2 dice.
# Extracted:
# reasoning:
# To find out how many 12 sided dice Mark and James need to buy, we need to calculate the number of 12 sided dice each of them already has and the total number of 12 sided dice Mark and James have in their bags combined.
#
# Mark has 10 dice, and 60% of them are 12 sided. So, Mark has 60% of 10 dice = 0.6 * 10 = 6 twelve-sided dice.
#
# James has 8 dice, and 75% of them are 12 sided. So, James has 75% of 8 dice = 0.75 * 8 = 6 twelve-sided dice.
#
# Mark and James have a total of 6 + 6 = 12 twelve-sided dice. They need a total of 14 dice.
#
# answer:
# Since they already have 12 twelve-sided dice, they need to buy 14 - 12 = 2 dice.
# -------------------- Question:
# Erin counts six trolls hiding by the path in the forest, 6 less than four times that number of trolls hiding under the bridge, and half as many trolls hiding in the plains as under the bridge. How many trolls did she count in total?
# Answer:
# 33
# Response:
# Under the bridge, the number of trolls is four times the number hiding by the path, which is 4 * 6 = 24.
#
# There are 6 less trolls hiding under the bridge, so the actual number of trolls under the bridge is 24 - 6 = 18.
#
# The number of trolls in the plains is half the number under the bridge, which is 18 / 2 = 9.
#
# The total number of trolls that Erin counted is the sum of trolls by the path, under the bridge, and in the plains: 6 + 18 + 9 = 33.
#
# <answer>33</answer>
# Extracted:
# 33
# -------------------- Question:
# Karen packs peanut butter sandwiches in her daughter's lunch 2 randomly chosen days of the week. The other 3 school days, she packs a ham sandwich. She packs a piece of cake on one randomly chosen day and cookies the other four days. What is the probability, expressed as a percentage, that Karen packs a ham sandwich and cake on the same day?
# Answer:
# 12
# Response:
# There are 5 school days. The probability that Karen packs a ham sandwich on a particular day is $\frac{3}{5}$, since she does a ham sandwich on $3$ out of the $5$ school days. The probability that she packs a cake on a particular day is $\frac{1}{5}$, since she packs a cake on $1$ out of the $5$ school days. Therefore, the probability that she packs a ham sandwich and cake on the same day is $\left(\frac{3}{5}\right)\left(\frac{1}{5}\right)=\frac{3}{25}.$ To express it as a percentage, we need to multiply it by $100$.
#
# So the probability that she packs a ham sandwich and cake on the same day is $\frac{3}{25} \times 100=12$%.
#
# Therefore,
# <reasoning>
# There are a total of 5 school days and she packs a ham sandwich on 3 days and a cake on 1 day. The probability of them happening simultaneously on the same day is calculated using the principle of multiplication of the probabilities (as they are independent events).
# </reasoning>
# <answer>
# 12%</answer>
# Extracted:
# 12%
# -------------------- Question:
# A four-layer pyramid is being built with each layer having three times as many sandstone blocks as the layer above it. The top layer is a single block. How many sandstone blocks are in the pyramid?
# Answer:
# 40
# Response:
# <logic>
# Let's break down the problem step by step:
#
# - The top layer has 1 block.
# - The second layer will have 3 times as many blocks as the top layer, so it will have 3 blocks.
# - The third layer will have 3 times as many blocks as the second layer, so it will have 3 x 3 = 9 blocks.
# - The fourth layer will have 3 times as many blocks as the third layer, so it will have 3 x 9 = 27 blocks.
#
# To find the total number of blocks in the pyramid, we need to add the blocks in each layer together: 1 + 3 + 9 + 27 =?
#
# We can also see that the sequence of the number of blocks in each layer is a geometric progression: 1, 3, 9, 27,...
# To find the total number of blocks in the pyramid, we can use the formula for the sum of a geometric progression:
#
# 1 + 3 + 3^2 + 3^3 = 1 + 3 + 9 + 27 = 1 + 3(1 + 3 + 3^2)
# = 1 + 3(1 + 3 + 3^2) = 1 + 3 (1 + 3 + 9) = 1 + 3(13) = 1 + 39 = 40.
#
# Therefore, the total number of blocks in the pyramid is 40.
#
# </logic>
# <answer>
# The final answer is 40.
# Extracted:
# The final answer is 40.
# -------------------- Question:
# The cost of Joe's new HVAC system is $20,000.  It includes 2 conditioning zones, each with 5 vents.  In dollars, what is the cost of the system per vent?
# Answer:
# 2,000
# Response:
# To find the cost of the system per vent, we need to first find the total number of vents in the system and then divide the total cost by this number.
#
# Each zone has 5 vents and there are 2 zones.
# Number of vents = 5 vents/zone * 2 zones = 10 vents.
#
# Now, we divide the total cost of the system by the total number of vents.
# Cost per vent = total cost / total number of vents = $20,000 / 10 vents = $2,000 per vent.
#
# <answer> $2,000 </answer>
# Extracted:
# $2,000
# -------------------- Question:
# Trent walked 4 blocks from his house to the bus stop. He rode the bus 7 blocks to the library. Later, he came home the same way. How many blocks did Trent travel in all?
# Answer:
# 22
# Response:
# TO find the total number of blocks Trent traveled, we need to calculate the distance to the library and then multiply it by 2 since he came back home the same way.
#
# Trent walked 4 blocks to the bus stop and rode the bus 7 blocks to the library. So the total number of blocks to the library is 4 + 7 = 11.
#
# Since he came back home the same way, we need to multiply the total blocks to the library by 2: 11 * 2 = 22.
#
# The answer is 22 blocks.
# Extracted:
# TO find the total number of blocks Trent traveled, we need to calculate the distance to the library and then multiply it by 2 since he came back home the same way.
#
# Trent walked 4 blocks to the bus stop and rode the bus 7 blocks to the library. So the total number of blocks to the library is 4 + 7 = 11.
#
# Since he came back home the same way, we need to multiply the total blocks to the library by 2: 11 * 2 = 22.
#
# The answer is 22 blocks.
# -------------------- Question:
# Lee had $10 and his friend had $8. They went to a restaurant where they ordered chicken wings for $6 and a chicken salad for $4. They also got 2 sodas for $1.00 each. The tax came to $3. How much change should they have received in total?
# Answer:
# 3
# Response:
# To find the amount they spent, we need to add the cost of the chicken wings, the chicken salad and the 2 sodas.
#
# Cost of the chicken wings: $6
# Cost of the chicken salad: $4
# Cost of the 2 sodas: $1 * 2 = $2
# Total cost: $6 + $4 + $2 = $12
#
# Since tax was added, we also need to add the tax to the total cost: $12 + $3 = $15
#
# They had a total of $10 + $8 = $18 initially. So their change should be their initial amount minus the amount spent: $18 - $15 = $3
#
# Therefore, they should have received $3 in change.
# Extracted:
# To find the amount they spent, we need to add the cost of the chicken wings, the chicken salad and the 2 sodas.
#
# Cost of the chicken wings: $6
# Cost of the chicken salad: $4
# Cost of the 2 sodas: $1 * 2 = $2
# Total cost: $6 + $4 + $2 = $12
#
# Since tax was added, we also need to add the tax to the total cost: $12 + $3 = $15
#
# They had a total of $10 + $8 = $18 initially. So their change should be their initial amount minus the amount spent: $18 - $15 = $3
#
# Therefore, they should have received $3 in change.
# -------------------- Question:
# Andy walks 50 meters from his house to school. After school, he comes back to the house and goes to the market. If he walks 140 meters in total, how many meters is the distance between the house and the market?
# Answer:
# 40
# Response:
# Assuming Andy's house is his starting point.
#
# The distance from his house to school is 50 meters and the distance from his school to his house is also 50 meters.  So, the total distance between his house and school is 50 * 2 = 100 meters.
#
# Given that the total distance covered by Andy is 140 meters, we can calculate the distance between the house and market as follows:
# - Total distance covered by Andy: 140 meters
# - Distance between house and school: 100 meters
# - Distance from school to market: Total distance - Distance between house and school = 140 - 100 = 40 meters
# Extracted:
# Assuming Andy's house is his starting point.
#
# The distance from his house to school is 50 meters and the distance from his school to his house is also 50 meters.  So, the total distance between his house and school is 50 * 2 = 100 meters.
#
# Given that the total distance covered by Andy is 140 meters, we can calculate the distance between the house and market as follows:
# - Total distance covered by Andy: 140 meters
# - Distance between house and school: 100 meters
# - Distance from school to market: Total distance - Distance between house and school = 140 - 100 = 40 meters
# -------------------- Question:
# Tara has been planning to buy a laptop which costs $1000. A computer shop accepts payment in installments of $65 per month provided that a 20% down payment is made. If Tara wants to pay an additional $20 for the down payment, how much will her balance be after paying for 4 months?
# Answer:
# 520
# Response:
# To find out how much Tara will have paid in total after 4 months, we need to calculate the down payment and the total amount paid in installments.
#
# First, let's calculate the down payment:
# The laptop costs $1000 and Tara wants to pay an additional $20, so a 20% down payment is 0.2 * 1020 = $204.
#
# Now, let's calculate the remaining balance after the down payment:
# balance = 1000 - 204 = $796
#
# Now, we need to calculate how much will be paid in installments for 4 months:
# monthly_payment = $65 * 4 = $260
#
# Now, let's calculate the remaining balance after 4 months:
# remaining_balance = 796 - 260 = $536
#
# Tara has already made the down payment, so now she only needs to make monthly payments.
# So, after paying for 4 months, her remaining balance will be $536.
# Extracted:
# To find out how much Tara will have paid in total after 4 months, we need to calculate the down payment and the total amount paid in installments.
#
# First, let's calculate the down payment:
# The laptop costs $1000 and Tara wants to pay an additional $20, so a 20% down payment is 0.2 * 1020 = $204.
#
# Now, let's calculate the remaining balance after the down payment:
# balance = 1000 - 204 = $796
#
# Now, we need to calculate how much will be paid in installments for 4 months:
# monthly_payment = $65 * 4 = $260
#
# Now, let's calculate the remaining balance after 4 months:
# remaining_balance = 796 - 260 = $536
#
# Tara has already made the down payment, so now she only needs to make monthly payments.
# So, after paying for 4 months, her remaining balance will be $536.
# -------------------- Question:
# Bill picked 50 apples from the orchard with his wife and two children.  He sends each of his kids to school with 3 apples for their two favorite teachers.  His wife Jill bakes two apple pies, using 10 apples per pie. How many apples does Bill have left?
# Answer:
# 24
# Response:
# To find out how many apples Bill has left, we need to calculate how many apples he used and subtract that from the total number of apples he picked.
#
# Bill had 50 apples initially and he sent each of his 2 kids with 3 apples to the school for their teachers, so 2 x 3 = 6 apples were used for the teachers. 6 apples were used for the teachers, and Jill used 2 x 10 = 20 apples for baking the pies.
#
# The total number of apples used is 20 (for the pies) + 6 (for the teachers) = 26 apples.
#
# Now, if Bill had 50 apples initially and 26 were used, he has 50 - 26 = 24 apples left.
#
# <answer> 24 </answer>
# Extracted:
# 24
# -------------------- Question:
# Each year Dani gets 4 pairs of two pants each as pay winning the best Amazon buyer of the season. If he initially had 50 pants, calculate the number of pants he'll have in 5 years.
# Answer:
# 90
# Response:
# To calculate the number of pants Dani will have in 5 years, we need to first find out how many pairs of pants he gets in 5 years.
#
# He gets 4 pairs of pants each year. So, in 5 years, he gets 4 pairs/year * 5 years = 20 pairs of pants.
#
# Since each pair of pants has 2 pants, he gets 20 pairs * 2 = 40 new pants.
#
# He already had 50 pants, so now he has 50 + 40 = 90 pants.
#
# The answer is 90.
# Extracted:
# To calculate the number of pants Dani will have in 5 years, we need to first find out how many pairs of pants he gets in 5 years.
#
# He gets 4 pairs of pants each year. So, in 5 years, he gets 4 pairs/year * 5 years = 20 pairs of pants.
#
# Since each pair of pants has 2 pants, he gets 20 pairs * 2 = 40 new pants.
#
# He already had 50 pants, so now he has 50 + 40 = 90 pants.
#
# The answer is 90.
# -------------------- Question:
# Jessica’s class is going to a farm for a field trip. The school will bring all 35 students in the class plus 4 adult chaperones. The farm entrance fee for students costs $5 and $6 for adults. How much will the school pay for the farm entrance in all?
# Answer:
# 199
# Response:
# To find the total cost, we need to calculate the cost for the students and the cost for the adults separately and then add them together.
#
# The cost for the students is $5 per student, and there are 35 students.
# $5 * 35 = $175
#
# The cost for the adults is $6 per adult, and there are 4 adults.
# $6 * 4 = $24
#
# Now, add the cost for the students and the adults together.
# $175 + $24 = $199
#
# The school will pay $199 for the farm entrance in all.
# Extracted:
# To find the total cost, we need to calculate the cost for the students and the cost for the adults separately and then add them together.
#
# The cost for the students is $5 per student, and there are 35 students.
# $5 * 35 = $175
#
# The cost for the adults is $6 per adult, and there are 4 adults.
# $6 * 4 = $24
#
# Now, add the cost for the students and the adults together.
# $175 + $24 = $199
#
# The school will pay $199 for the farm entrance in all.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2401788477.py in <cell line: 0>()
#      12     train_dataset = dataset,
#      13 )
# ---> 14 trainer.train()
#
# /content/unsloth_compiled_cache/UnslothGRPOTrainer.py in wrapper(self, *args, **kwargs)
#      51         if hasattr(self, 'model') and hasattr(self.model, "for_training"):
#      52             self.model.for_training()
# ---> 53         output = f(self, *args, **kwargs)
#      54         # Return inference mode
#      55         if hasattr(self, 'model') and hasattr(self.model, "for_inference"):
#
# /usr/local/lib/python3.12/dist-packages/transformers/trainer.py in train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    2236                 hf_hub_utils.enable_progress_bars()
#    2237         else:
# -> 2238             return inner_training_loop(
#    2239                 args=args,
#    2240                 resume_from_checkpoint=resume_from_checkpoint,
#
# /usr/local/lib/python3.12/dist-packages/unsloth/models/llama.py in _fast_inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#
# /usr/local/lib/python3.12/dist-packages/unsloth/models/_utils.py in _unsloth_training_step(self, model, inputs, num_items_in_batch)
#
# /usr/local/lib/python3.12/dist-packages/trl/extras/profiling.py in wrapper(self, *args, **kwargs)
#      96     def wrapper(self, *args, **kwargs):
#      97         with profiling_context(self, func.__name__):
# ---> 98             return func(self, *args, **kwargs)
#      99
#     100     return wrapper
#
# /content/unsloth_compiled_cache/UnslothGRPOTrainer.py in _prepare_inputs(self, generation_batch)
#    2011             if self._step % generate_every == 0 or self._buffered_inputs is None:
#    2012                 # self._buffered_inputs=None can occur when resuming from a checkpoint
# -> 2013                 generation_batch = self._generate_and_score_completions(generation_batch)
#    2014                 generation_batch = split_pixel_values_by_grid(generation_batch)
#    2015
#
# /content/unsloth_compiled_cache/UnslothGRPOTrainer.py in _generate_and_score_completions(self, inputs)
#    2257
#    2258                 with profiling_context(self, "vLLM.generate"):
# -> 2259                     all_outputs = self.llm.generate(vllm_inputs, sampling_params=sampling_params, use_tqdm=False, lora_request = self.model.load_lora('grpo_trainer_lora_model', load_tensors = True))
#    2260
#    2261                 completion_ids = [output.token_ids for outputs in all_outputs for output in outputs.outputs]
#
# /usr/local/lib/python3.12/dist-packages/unsloth_zoo/vllm_utils.py in new_generate(self, *args, **kwargs)
#     649             if check_sleep_mode(self):
#     650                 self.wake_up()
# --> 651             return original_generate(self,*args, **kwargs)
#     652         return new_generate
#     653     pass
#
# /usr/local/lib/python3.12/dist-packages/vllm/utils/__init__.py in inner(*args, **kwargs)
#    1290                     )
#    1291
# -> 1292             return fn(*args, **kwargs)
#    1293
#    1294         return inner  # type: ignore
#
# /usr/local/lib/python3.12/dist-packages/vllm/entrypoints/llm.py in generate(self, prompts, sampling_params, prompt_token_ids, use_tqdm, lora_request, prompt_adapter_request, guided_options_request, priority)
#     508         )
#     509
# --> 510         outputs = self._run_engine(use_tqdm=use_tqdm)
#     511         return self.engine_class.validate_outputs(outputs, RequestOutput)
#     512
#
# /usr/local/lib/python3.12/dist-packages/vllm/entrypoints/llm.py in _run_engine(self, use_tqdm)
#    1568         total_out_toks = 0
#    1569         while self.llm_engine.has_unfinished_requests():
# -> 1570             step_outputs = self.llm_engine.step()
#    1571             for output in step_outputs:
#    1572                 if output.finished:
#
# /usr/local/lib/python3.12/dist-packages/vllm/engine/llm_engine.py in step(self)
#    1354
#    1355             try:
# -> 1356                 outputs = self.model_executor.execute_model(
#    1357                     execute_model_req=execute_model_req)
#    1358                 self._skip_scheduling_next_step = False
#
# /usr/local/lib/python3.12/dist-packages/vllm/executor/executor_base.py in execute_model(self, execute_model_req)
#     139         self, execute_model_req: ExecuteModelRequest
#     140     ) -> Optional[List[Union[SamplerOutput, PoolerOutput]]]:
# --> 141         output = self.collective_rpc("execute_model",
#     142                                      args=(execute_model_req, ))
#     143         return output[0]
#
# /usr/local/lib/python3.12/dist-packages/vllm/executor/uniproc_executor.py in collective_rpc(self, method, timeout, args, kwargs)
#      55         if kwargs is None:
#      56             kwargs = {}
# ---> 57         answer = run_method(self.driver_worker, method, args, kwargs)
#      58         return [answer]
#      59
#
# /usr/local/lib/python3.12/dist-packages/vllm/utils/__init__.py in run_method(obj, method, args, kwargs)
#    2734     else:
#    2735         func = partial(method, obj)  # type: ignore
# -> 2736     return func(*args, **kwargs)
#    2737
#    2738
#
# /usr/local/lib/python3.12/dist-packages/vllm/worker/worker_base.py in execute_model(self, execute_model_req)
#     418                     "model_execute_time", torch.tensor(0)).item()
#     419
# --> 420         output = self.model_runner.execute_model(
#     421             model_input=model_input,
#     422             kv_caches=self.kv_cache[worker_input.virtual_engine]
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     114     def decorate_context(*args, **kwargs):
#     115         with ctx_factory():
# --> 116             return func(*args, **kwargs)
#     117
#     118     return decorate_context
#
# /usr/local/lib/python3.12/dist-packages/vllm/worker/model_runner.py in execute_model(self, model_input, kv_caches, intermediate_tensors, num_steps, **kwargs)
#    1904                 self.sampler.include_gpu_probs_tensor = True
#    1905
# -> 1906             output: SamplerOutput = self.sampler(
#    1907                 logits=logits,
#    1908                 sampling_metadata=model_input.sampling_metadata,
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1749             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750         else:
# -> 1751             return self._call_impl(*args, **kwargs)
#    1752
#    1753     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1760                 or _global_backward_pre_hooks or _global_backward_hooks
#    1761                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762             return forward_call(*args, **kwargs)
#    1763
#    1764         result = None
#
# /usr/local/lib/python3.12/dist-packages/vllm/model_executor/layers/sampler.py in forward(self, logits, sampling_metadata)
#     296
#     297         # Sample the next tokens.
# --> 298         maybe_deferred_sample_results, maybe_sampled_tokens_tensor = _sample(
#     299             probs,
#     300             logprobs,
#
# /usr/local/lib/python3.12/dist-packages/vllm/model_executor/layers/sampler.py in _sample(probs, logprobs, sampling_metadata, sampling_tensors, include_gpu_probs_tensor, modify_greedy_probs)
#     756         sampled_token_ids_tensor: A tensor of sampled token ids.
#     757     """
# --> 758     return _sample_with_torch(
#     759         probs,
#     760         logprobs,
#
# /usr/local/lib/python3.12/dist-packages/vllm/model_executor/layers/sampler.py in _sample_with_torch(probs, logprobs, sampling_metadata, sampling_tensors, include_gpu_probs_tensor, modify_greedy_probs)
#     725         # This also converts the sampler output to a Python object.
#     726         # Return Pythonized sampler result & sampled token ids
# --> 727         return get_pythonized_sample_results(
#     728             maybe_deferred_args), sampled_token_ids_tensor
#     729     else:
#
# /usr/local/lib/python3.12/dist-packages/vllm/model_executor/layers/sampler.py in get_pythonized_sample_results(sample_result_args)
#     602             sample_results = _greedy_sample(seq_groups, greedy_samples)
#     603         elif sampling_type in (SamplingType.RANDOM, SamplingType.RANDOM_SEED):
# --> 604             sample_results = _random_sample(seq_groups,
#     605                                             multinomial_samples[sampling_type])
#     606         sample_results_dict.update(zip(seq_group_id, sample_results))
#
# /usr/local/lib/python3.12/dist-packages/vllm/model_executor/layers/sampler.py in _random_sample(selected_seq_groups, random_samples)
#     494     """
#     495     # Find the maximum n value of the prompt phase requests.
# --> 496     random_samples = random_samples.cpu()
#     497     sample_idx = 0
#     498     results: SampleResultType = []
#
# KeyboardInterrupt:

# %% [markdown]
# <a name="Inference"></a>
# ### Inference
# Now let's try the model we just trained! First, let's first try the model without any GRPO trained:

# %%
text = tokenizer.apply_chat_template([
    {"role" : "user", "content" : "Umiesz mowic po polsku?"},
], tokenize = False, add_generation_prompt = True)

from vllm import SamplingParams
sampling_params = SamplingParams(
    temperature = 0.8,
    top_p = 0.95,
    max_tokens = 1024,
)
output = model.fast_generate(
    [text],
    sampling_params = sampling_params,
    lora_request = None,
)[0].outputs[0].text

output
# Out:
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# 'Tak, mogę mówić po polsku. Czy chcesz porozmawiać o czymś konkretnym, czy potrzebujesz pomocy z jakiegoś zagadnienia?'

# %% [markdown]
# And now with the LoRA we just trained with GRPO - we first save the LoRA first!

# %%
model.save_lora("grpo_saved_lora")

# %% [markdown]
# Now we load the LoRA and test:

# %%
text = tokenizer.apply_chat_template([
    {"role" : "system", "content" : SYSTEM_PROMPT},
    {"role" : "user", "content" : "Calculate pi."},
], tokenize = False, add_generation_prompt = True)

from vllm import SamplingParams
sampling_params = SamplingParams(
    temperature = 0.8,
    top_p = 0.95,
    max_tokens = 1024,
)
output = model.fast_generate(
    text,
    sampling_params = sampling_params,
    lora_request = model.load_lora("grpo_saved_lora"),
)[0].outputs[0].text

output

# %% [markdown]
# Our reasoning model is much better - it's not always correct, since we only trained it for an hour or so - it'll be better if we extend the sequence length and train for longer!

# %% [markdown]
# <a name="Save"></a>
# ### Saving to float16 for VLLM
#
# We also support saving to `float16` directly. Select `merged_16bit` for float16 or `merged_4bit` for int4. We also allow `lora` adapters as a fallback. Use `push_to_hub_merged` to upload to your Hugging Face account! You can go to https://huggingface.co/settings/tokens for your personal tokens.

# %%
# Merge to 16bit
if False: model.save_pretrained_merged("model", tokenizer, save_method = "merged_16bit",)
if False: model.push_to_hub_merged("hf/model", tokenizer, save_method = "merged_16bit", token = "")

# Merge to 4bit
if False: model.save_pretrained_merged("model", tokenizer, save_method = "merged_4bit",)
if False: model.push_to_hub_merged("hf/model", tokenizer, save_method = "merged_4bit", token = "")

# Just LoRA adapters
if False:
    model.save_pretrained("model")
    tokenizer.save_pretrained("model")
if False:
    model.push_to_hub("hf/model", token = "")
    tokenizer.push_to_hub("hf/model", token = "")

# %% [markdown]
# ### GGUF / llama.cpp Conversion
# To save to `GGUF` / `llama.cpp`, we support it natively now! We clone `llama.cpp` and we default save it to `q8_0`. We allow all methods like `q4_k_m`. Use `save_pretrained_gguf` for local saving and `push_to_hub_gguf` for uploading to HF.
#
# Some supported quant methods (full list on our [Wiki page](https://github.com/unslothai/unsloth/wiki#gguf-quantization-options)):
# * `q8_0` - Fast conversion. High resource use, but generally acceptable.
# * `q4_k_m` - Recommended. Uses Q6_K for half of the attention.wv and feed_forward.w2 tensors, else Q4_K.
# * `q5_k_m` - Recommended. Uses Q6_K for half of the attention.wv and feed_forward.w2 tensors, else Q5_K.
#
# [**NEW**] To finetune and auto export to Ollama, try our [Ollama notebook](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3_(8B)-Ollama.ipynb)

# %%
# Save to 8bit Q8_0
if False: model.save_pretrained_gguf("model", tokenizer,)
# Remember to go to https://huggingface.co/settings/tokens for a token!
# And change hf to your username!
if False: model.push_to_hub_gguf("hf/model", tokenizer, token = "")

# Save to 16bit GGUF
if False: model.save_pretrained_gguf("model", tokenizer, quantization_method = "f16")
if False: model.push_to_hub_gguf("hf/model", tokenizer, quantization_method = "f16", token = "")

# Save to q4_k_m GGUF
if False: model.save_pretrained_gguf("model", tokenizer, quantization_method = "q4_k_m")
if False: model.push_to_hub_gguf("hf/model", tokenizer, quantization_method = "q4_k_m", token = "")

# Save to multiple GGUF options - much faster if you want multiple!
if False:
    model.push_to_hub_gguf(
        "hf/model", # Change hf to your username!
        tokenizer,
        quantization_method = ["q4_k_m", "q8_0", "q5_k_m",],
        token = "",
    )

# %% [markdown]
# Now, use the `model-unsloth.gguf` file or `model-unsloth-Q4_K_M.gguf` file in llama.cpp.
#
# And we're done! If you have any questions on Unsloth, we have a [Discord](https://discord.gg/unsloth) channel! If you find any bugs or want to keep updated with the latest LLM stuff, or need help, join projects etc, feel free to join our Discord!
#
# Some other links:
# 1. Train your own reasoning model - Llama GRPO notebook [Free Colab](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3.1_(8B)-GRPO.ipynb)
# 2. Saving finetunes to Ollama. [Free notebook](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3_(8B)-Ollama.ipynb)
# 3. Llama 3.2 Vision finetuning - Radiography use case. [Free Colab](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3.2_(11B)-Vision.ipynb)
# 6. See notebooks for DPO, ORPO, Continued pretraining, conversational finetuning and more on our [documentation](https://docs.unsloth.ai/get-started/unsloth-notebooks)!
#
# <div class="align-center">
#   <a href="https://unsloth.ai"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
#   <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord.png" width="145"></a>
#   <a href="https://docs.unsloth.ai/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a>
#
#   Join Discord if you need help + ⭐️ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐️
# </div>
